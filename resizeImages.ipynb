# %%
import cv2
from google.colab.patches import cv2_imshow # for image display

  
src = cv2.imread('/content/drive/MyDrive/TFM-IA/ELCXVZJYL152.jpg', cv2.IMREAD_UNCHANGED)
 
#Porcentaje en el que se redimensiona la imagen
scale_percent = 50
 
width = int(416)
height = int(256)
 
# dsize
dsize = (width, height)
 
# cambiar el tamaño de la image
output = cv2.resize(src, dsize)
 
cv2.imwrite('/content/drive/MyDrive/TFM-IA/1cv2-resize-image-50.png',output)
# Out:
# True

# %%
import os
import cv2
from pathlib import Path
import glob
# Crear libreria
for filepath in glob.iglob('/content/drive/MyDrive/TFM-IA/snail-spicie/*.*'):
  print(filepath)
  src = cv2.imread(filepath, cv2.IMREAD_UNCHANGED)
  #la nueva dimensión de la imagen
  width = int(1333)
  height = int(1000)
  # dsize
  dsize = (width, height)
  # cambiar el tamaño de la image
  output = cv2.resize(src, dsize)
  print(cv2.imwrite(filepath+"A.png",output)) 
  print(filepath+"A"+"png")
# Out:
# /content/drive/MyDrive/TFM-IA/snail-spicie/IMG_6410.JPEG
# True
# /content/drive/MyDrive/TFM-IA/snail-spicie/IMG_6410.JPEGApng
# /content/drive/MyDrive/TFM-IA/snail-spicie/IMG_6411.JPEG
# True
# /content/drive/MyDrive/TFM-IA/snail-spicie/IMG_6411.JPEGApng
# /content/drive/MyDrive/TFM-IA/snail-spicie/4_2bis.JPEG
# True
# /content/drive/MyDrive/TFM-IA/snail-spicie/4_2bis.JPEGApng
# /content/drive/MyDrive/TFM-IA/snail-spicie/IMG_6412.JPEG
# True
# /content/drive/MyDrive/TFM-IA/snail-spicie/IMG_6412.JPEGApng
# /content/drive/MyDrive/TFM-IA/snail-spicie/IMG_6413.JPEG
# True
# /content/drive/MyDrive/TFM-IA/snail-spicie/IMG_6413.JPEGApng
# /content/drive/MyDrive/TFM-IA/snail-spicie/3_2bis.JPEG
# True
# /content/drive/MyDrive/TFM-IA/snail-spicie/3_2bis.JPEGApng
# /content/drive/MyDrive/TFM-IA/snail-spicie/IMG_6408.JPEG
# True
# /content/drive/MyDrive/TFM-IA/snail-spicie/IMG_6408.JPEGApng
# /content/drive/MyDrive/TFM-IA/snail-spicie/IMG_6407.JPEG
# True
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import glob

for filepath in glob.iglob('drive/test/*.txt'):
    if filepath.endswith('/filename.txt'):
        print(filepath)
# Out:
# /content/drive/MyDrive/TFM-IA/E5X359IPPIQW.jpg
# /content/drive/MyDrive/TFM-IA/DXDD7IAYQXKO.jpg
# /content/drive/MyDrive/TFM-IA/DKV6N6S91F9Q.jpg
# /content/drive/MyDrive/TFM-IA/DS8DFAXRZ3YY.jpg
# /content/drive/MyDrive/TFM-IA/DH7DFYAMG1F9.jpg
# /content/drive/MyDrive/TFM-IA/E5HKXM1PGIIO.jpg
# /content/drive/MyDrive/TFM-IA/DGCEV7ZJZT28.jpg
# /content/drive/MyDrive/TFM-IA/DTH51CXKWU5U.jpg
# /content/drive/MyDrive/TFM-IA/E0TRRAR89QZ3.jpg
# /content/drive/MyDrive/TFM-IA/DFVCR6YYU6D8.jpg
# /content/drive/MyDrive/TFM-IA/79GSA90E270P.jpg
# /content/drive/MyDrive/TFM-IA/3MVO43HHOTV1.jpg
# /content/drive/MyDrive/TFM-IA/70NSB5E0K66V.jpg
# /content/drive/MyDrive/TFM-IA/CDPL2K7XSIYA.jpg
# /content/drive/MyDrive/TFM-IA/AFHBM4HRIGZI.jpg
# /content/drive/MyDrive/TFM-IA/08DNYKBB9PGR.jpg
# /content/drive/MyDrive/TFM-IA/7JNBQ778EYG9.jpg
# /content/drive/MyDrive/TFM-IA/CEUCBRZ1STXS.jpg
# /content/drive/MyDrive/TFM-IA/8J0Y6CR4H2YM.jpg
# /content/drive/MyDrive/TFM-IA/2M1HXUL4PD1P.jpg
# ...
